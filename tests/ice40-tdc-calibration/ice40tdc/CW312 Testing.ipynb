# %% [markdown]
# ```
# pip install apio
# ```
#
# On Windows if you get a permission error:
#
# ```
# (python.exe -m pip install apio)
# ```
#
# Once `apio` is installed, installed the `oss-cad-suite`:
#
# ```
# apio install oss-cad-suite
# ```
#
# Other links:
# https://github.com/YosysHQ/nextpnr/issues/660
# https://github.com/tgingold/OpenTDC/tree/master

# %%
import time
from glitchmeter import GlitchMeter
from datetime import datetime
import json
import struct
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /home/george/research-local/BitCrusher/tests/.venv/lib/python3.14/site-packages/chipwhisperer/capture/trace/TraceWhisperer.py:31: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources # type: ignore

# %%
gm = GlitchMeter(daccom="/dev/ttyACM0", dir="rtl")
# Out:
# scope.gain.mode                          changed from low                       to high
# scope.gain.gain                          changed from 0                         to 22
# scope.gain.db                            changed from 15.0                      to 25.091743119266056
# scope.adc.samples                        changed from 131124                    to 5000
# scope.clock.clkgen_freq                  changed from 0                         to 7363636.363636363
# scope.clock.adc_freq                     changed from 0                         to 29454545.454545453
# scope.io.tio1                            changed from serial_tx                 to serial_rx
# scope.io.tio2                            changed from serial_rx                 to serial_tx
# scope.io.hs2                             changed from None                      to clkgen
# scope.io.cdc_settings                    changed from bytearray(b'\x01\x00\x00\x00') to bytearray(b'\x00\x00\x00\x00')
# scope.glitch.phase_shift_steps           changed from 0                         to 4592
# scope.trace.capture.trigger_source       changed from trace trigger, rule #0    to firmware trigger

# %%
scope = gm.scope
scope.clock.adc_mul = 1
scope.clock.clkgen_freq = 20E6

scope.glitch.enabled = True

scope.glitch.clk_src = "pll"
scope.glitch.trigger_src = "ext_single"

# %%
NUM_ELEMENTS = 3

for mv in range(900, 1300, 10):
    good = False
    
    while good is False:
        scope = gm.scope
        gm.set_coremv(mv)

        time.sleep(0.25)

        scope.glitch.enabled = True

        gm.build_and_load(NUM_ELEMENTS)
        time.sleep(0.25)

        scope.io.tio1 = True
        time.sleep(0.01)
        scope.io.tio1 = False

        pattern = gm.getpattern(True)
        pltdata = []

        p  = pattern[0]
        bpat = bin(int(p.hex(), 16))
        cnt = bpat.count('1')

        if cnt != 32:
            good = True

            #print(bpat)
            print("%d mV = %d"%(mv, cnt))
    
# I believe I'm getting bad results from this because I don't have the iCE40 configured right for it
# to recieve the messages. Look at comment at top of `glitchmeter.py` .
# Out:
# Using env default (fomu)
# Setting shell vars.
# --------------------------------------------------------------------------------
# scons: `build' is up to date.
# ========================= [SUCCESS] Took 0.13 seconds ==========================
# 00000001001000110100010101100111
# 11011110101011011011111011101111
# 11111110111011011111101011001110
# 11001010111111101011111011101111
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 900 mV = 12
# Using env default (fomu)
# Setting shell vars.
# --------------------------------------------------------------------------------
# scons: `build' is up to date.
# ========================= [SUCCESS] Took 0.10 seconds ==========================
# 00000001001000110100010101100111
# 11011110101011011011111011101111
# 11111110111011011111101011001110
# 11001010111111101011111011101111
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 910 mV = 12
# Using env default (fomu)
# Setting shell vars.
# --------------------------------------------------------------------------------
# scons: `build' is up to date.
# ========================= [SUCCESS] Took 0.10 seconds ==========================
# 00000001001000110100010101100111
# 11011110101011011011111011101111
# 11111110111011011111101011001110
# 11001010111111101011111011101111
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 920 mV = 12
# Using env default (fomu)
# Setting shell vars.
# --------------------------------------------------------------------------------
# scons: `build' is up to date.
# ========================= [SUCCESS] Took 0.10 seconds ==========================
# 00000001001000110100010101100111
# 11011110101011011011111011101111
# 11111110111011011111101011001110
# 11001010111111101011111011101111
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 930 mV = 12
# Using env default (fomu)
# Setting shell vars.
# --------------------------------------------------------------------------------
# scons: `build' is up to date.
# ========================= [SUCCESS] Took 0.10 seconds ==========================
# 00000001001000110100010101100111
# 11011110101011011011111011101111
# 11111110111011011111101011001110
# 11001010111111101011111011101111
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 940 mV = 12
# Using env default (fomu)
# Setting shell vars.
# --------------------------------------------------------------------------------
# scons: `build' is up to date.
# ========================= [SUCCESS] Took 0.11 seconds ==========================
# 00000001001000110100010101100111
# 11011110101011011011111011101111
# 11111110111011011111101011001110
# 11001010111111101011111011101111
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 950 mV = 12
# Using env default (fomu)
# Setting shell vars.
# --------------------------------------------------------------------------------
# scons: `build' is up to date.
# ========================= [SUCCESS] Took 0.11 seconds ==========================
# 00000001001000110100010101100111
# 11011110101011011011111011101111
# 11111110111011011111101011001110
# 11001010111111101011111011101111
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 960 mV = 12
# Using env default (fomu)
# Setting shell vars.
# --------------------------------------------------------------------------------
# scons: `build' is up to date.
# ========================= [SUCCESS] Took 0.11 seconds ==========================
# 00000001001000110100010101100111
# 11011110101011011011111011101111
# 11111110111011011111101011001110
# 11001010111111101011111011101111
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 970 mV = 12
# Using env default (fomu)
# Setting shell vars.
# --------------------------------------------------------------------------------
# scons: `build' is up to date.
# ========================= [SUCCESS] Took 0.11 seconds ==========================
# 00000001001000110100010101100111
# 11011110101011011011111011101111
# 11111110111011011111101011001110
# 11001010111111101011111011101111
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 980 mV = 12
# Using env default (fomu)
# Setting shell vars.
# --------------------------------------------------------------------------------
# scons: `build' is up to date.
# ========================= [SUCCESS] Took 0.11 seconds ==========================
# 00000001001000110100010101100111
# 11011110101011011011111011101111
# 11111110111011011111101011001110
# 11001010111111101011111011101111
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 990 mV = 12
# Using env default (fomu)
# Setting shell vars.
# --------------------------------------------------------------------------------
# scons: `build' is up to date.
# ========================= [SUCCESS] Took 0.11 seconds ==========================
# 00000001001000110100010101100111
# 11011110101011011011111011101111
# 11111110111011011111101011001110
# 11001010111111101011111011101111
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 1000 mV = 12
# Using env default (fomu)
# Setting shell vars.
# --------------------------------------------------------------------------------
# scons: `build' is up to date.
# ========================= [SUCCESS] Took 0.10 seconds ==========================
# 00000001001000110100010101100111
# 11011110101011011011111011101111
# 11111110111011011111101011001110
# 11001010111111101011111011101111
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 1010 mV = 12
# Using env default (fomu)
# Setting shell vars.
# --------------------------------------------------------------------------------
# scons: `build' is up to date.
# ========================= [SUCCESS] Took 0.12 seconds ==========================
# 00000001001000110100010101100111
# 11011110101011011011111011101111
# 11111110111011011111101011001110
# 11001010111111101011111011101111
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 1020 mV = 12
# Using env default (fomu)
# Setting shell vars.
# --------------------------------------------------------------------------------
# scons: `build' is up to date.
# ========================= [SUCCESS] Took 0.13 seconds ==========================
# 00000001001000110100010101100111
# 11011110101011011011111011101111
# 11111110111011011111101011001110
# 11001010111111101011111011101111
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 1030 mV = 12
# Using env default (fomu)
# Setting shell vars.
# --------------------------------------------------------------------------------
# scons: `build' is up to date.
# ========================= [SUCCESS] Took 0.11 seconds ==========================
# 00000001001000110100010101100111
# 11011110101011011011111011101111
# 11111110111011011111101011001110
# 11001010111111101011111011101111
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 1040 mV = 12
# Using env default (fomu)
# Setting shell vars.
# --------------------------------------------------------------------------------
# scons: `build' is up to date.
# ========================= [SUCCESS] Took 0.11 seconds ==========================
# 00000001001000110100010101100111
# 11011110101011011011111011101111
# 11111110111011011111101011001110
# 11001010111111101011111011101111
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 1050 mV = 12
# Using env default (fomu)
# Setting shell vars.
# --------------------------------------------------------------------------------
# scons: `build' is up to date.
# ========================= [SUCCESS] Took 0.11 seconds ==========================
# 00000001001000110100010101100111
# 11011110101011011011111011101111
# 11111110111011011111101011001110
# 11001010111111101011111011101111
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 1060 mV = 12
# Using env default (fomu)
# Setting shell vars.
# --------------------------------------------------------------------------------
# scons: `build' is up to date.
# ========================= [SUCCESS] Took 0.11 seconds ==========================
# 00000001001000110100010101100111
# 11011110101011011011111011101111
# 11111110111011011111101011001110
# 11001010111111101011111011101111
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 1070 mV = 12
# Using env default (fomu)
# Setting shell vars.
# --------------------------------------------------------------------------------
# scons: `build' is up to date.
# ========================= [SUCCESS] Took 0.11 seconds ==========================
# 00000001001000110100010101100111
# 11011110101011011011111011101111
# 11111110111011011111101011001110
# 11001010111111101011111011101111
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 1080 mV = 12
# Using env default (fomu)
# Setting shell vars.
# --------------------------------------------------------------------------------
# scons: `build' is up to date.
# ========================= [SUCCESS] Took 0.11 seconds ==========================
# 00000001001000110100010101100111
# 11011110101011011011111011101111
# 11111110111011011111101011001110
# 11001010111111101011111011101111
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 1090 mV = 12
# Using env default (fomu)
# Setting shell vars.
# --------------------------------------------------------------------------------
# scons: `build' is up to date.
# ========================= [SUCCESS] Took 0.11 seconds ==========================
# 00000001001000110100010101100111
# 11011110101011011011111011101111
# 11111110111011011111101011001110
# 11001010111111101011111011101111
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# ...
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 1230 mV = 12
# Using env default (fomu)
# Setting shell vars.
# --------------------------------------------------------------------------------
# scons: `build' is up to date.
# ========================= [SUCCESS] Took 0.11 seconds ==========================
# 00000001001000110100010101100111
# 11011110101011011011111011101111
# 11111110111011011111101011001110
# 11001010111111101011111011101111
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 1240 mV = 12
# Using env default (fomu)
# Setting shell vars.
# --------------------------------------------------------------------------------
# scons: `build' is up to date.
# ========================= [SUCCESS] Took 0.11 seconds ==========================
# 00000001001000110100010101100111
# 11011110101011011011111011101111
# 11111110111011011111101011001110
# 11001010111111101011111011101111
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 1250 mV = 12
# Using env default (fomu)
# Setting shell vars.
# --------------------------------------------------------------------------------
# scons: `build' is up to date.
# ========================= [SUCCESS] Took 0.11 seconds ==========================
# 00000001001000110100010101100111
# 11011110101011011011111011101111
# 11111110111011011111101011001110
# 11001010111111101011111011101111
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 1260 mV = 12
# Using env default (fomu)
# Setting shell vars.
# --------------------------------------------------------------------------------
# scons: `build' is up to date.
# ========================= [SUCCESS] Took 0.11 seconds ==========================
# 00000001001000110100010101100111
# 11011110101011011011111011101111
# 11111110111011011111101011001110
# 11001010111111101011111011101111
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 1270 mV = 12
# Using env default (fomu)
# Setting shell vars.
# --------------------------------------------------------------------------------
# scons: `build' is up to date.
# ========================= [SUCCESS] Took 0.11 seconds ==========================
# 00000001001000110100010101100111
# 11011110101011011011111011101111
# 11111110111011011111101011001110
# 11001010111111101011111011101111
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 1280 mV = 12
# Using env default (fomu)
# Setting shell vars.
# --------------------------------------------------------------------------------
# scons: `build' is up to date.
# ========================= [SUCCESS] Took 0.11 seconds ==========================
# 00000001001000110100010101100111
# 11011110101011011011111011101111
# 11111110111011011111101011001110
# 11001010111111101011111011101111
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 00000000000000000000000000000000
# 1290 mV = 12

# %%
plt.figure()

for s in """900 mV = 27
910 mV = 30
920 mV = 29
930 mV = 30
940 mV = 29
950 mV = 27
960 mV = 26
970 mV = 26
980 mV = 26
990 mV = 23
1000 mV = 21
1010 mV = 19
1020 mV = 19
1030 mV = 18
1040 mV = 17
1050 mV = 17
1060 mV = 16
1070 mV = 15
1080 mV = 14
1090 mV = 13
1100 mV = 12
1110 mV = 9
1120 mV = 9
1130 mV = 8
1140 mV = 6
1150 mV = 6
1160 mV = 3
1170 mV = 2
1180 mV = 2
1190 mV = 2
1200 mV = 2
1210 mV = 2
1220 mV = 1
1230 mV = 0
1240 mV = 0
1250 mV = 0
1260 mV = 0
1270 mV = 0
1280 mV = 0
1290 mV = 0""".split("\n"):
    values = s.split(" = ")
    mv = int(values[0][:-3])
    result = int(values[1])
    
    plt.plot(mv, result, '.r')

# %%
for i in range(0, 32):
    NUM_ELEMENTS = i
    print("Elements = %d"%i)

    scope = gm.scope

    scope.glitch.enabled = True

    gm.build_and_load(NUM_ELEMENTS)

    scope.io.tio1 = True
    time.sleep(0.01)
    scope.io.tio1 = False

    pattern = gm.getpattern(False)
    pltdata = []

    for p in pattern:
        bpat = bin(int(p.hex(), 16))
        print(bpat)
        print(bpat.count('1'))
        res = int(p.hex(), 16)

        break
# Out:
# Elements = 0
# 0b11111111111111111111111111111111
# 32
# Elements = 1
# 0b0
# 0
# Elements = 2
# 0b11111111111111111111111111111111
# 32
# Elements = 3
# 0b11111111111111111111111111111111
# 32
# Elements = 4
# 0b0
# 0
# Elements = 5
# 0b11111111111111111111111111111111
# 32
# Elements = 6
# 0b11111111111111111111111111111111
# 32
# Elements = 7
# 0b11111111111111111111111111111111
# 32
# Elements = 8
# 0b0
# 0
# Elements = 9
# 0b11111111111111111111111111111111
# 32
# Elements = 10
# 0b11111111111111111111111111111111
# 32
# Elements = 11
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 9
#       5 scope = gm.scope
#       7 scope.glitch.enabled = True
# ----> 9 gm.build_and_load(NUM_ELEMENTS)
#      11 scope.io.tio1 = True
#      12 time.sleep(0.01)
#
# File ~\Dropbox (NewAE Technology Inc)\engineering\research\ice40-glitch-meter\cw308_real\glitchmeter.py:107, in GlitchMeter.build_and_load(self, num_delay_elements, trigger_mode, trigger_condition)
#     104 def build_and_load(self, num_delay_elements=32, trigger_mode="always", trigger_condition="~wdata[9]"):
#     106     self.YB.output_settings(num_delay_elements, trigger_mode, trigger_condition)
# --> 107     self.YB.build()
#     109     self.ice.erase_and_init()
#     110     self.ice.program(os.path.join("rtl", "hardware.bin"))
#
# File ~\Dropbox (NewAE Technology Inc)\engineering\research\ice40-glitch-meter\cw308_real\glitchmeter.py:74, in YosysBuild.build(self)
#      73 def build(self):
# ---> 74     subprocess.run("apio build", cwd=self.dir, shell=True, check=True)
#
# File C:\CHIPWH~4\cw\home\portable\WPy64-31080\python-3.10.8.amd64\lib\subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     503 with Popen(*popenargs, **kwargs) as process:
#     504     try:
# --> 505         stdout, stderr = process.communicate(input, timeout=timeout)
#     506     except TimeoutExpired as exc:
#     507         process.kill()
#
# File C:\CHIPWH~4\cw\home\portable\WPy64-31080\python-3.10.8.amd64\lib\subprocess.py:1146, in Popen.communicate(self, input, timeout)
#    1144         stderr = self.stderr.read()
#    1145         self.stderr.close()
# -> 1146     self.wait()
#    1147 else:
#    1148     if timeout is not None:
#
# File C:\CHIPWH~4\cw\home\portable\WPy64-31080\python-3.10.8.amd64\lib\subprocess.py:1209, in Popen.wait(self, timeout)
#    1207     endtime = _time() + timeout
#    1208 try:
# -> 1209     return self._wait(timeout=timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # The first keyboard interrupt waits briefly for the child to
#    1213     # exit under the common assumption that it also received the ^C
#    1214     # generated SIGINT and will exit rapidly.
#    1215     if timeout is not None:
#
# File C:\CHIPWH~4\cw\home\portable\WPy64-31080\python-3.10.8.amd64\lib\subprocess.py:1490, in Popen._wait(self, timeout)
#    1487     timeout_millis = int(timeout * 1000)
#    1488 if self.returncode is None:
#    1489     # API note: Returns immediately if timeout_millis == 0.
# -> 1490     result = _winapi.WaitForSingleObject(self._handle,
#    1491                                          timeout_millis)
#    1492     if result == _winapi.WAIT_TIMEOUT:
#    1493         raise TimeoutExpired(self.args, timeout)
#
# KeyboardInterrupt:

# %%
scope.io.tio1 = True
time.sleep(0.01)
scope.io.tio1 = False

pattern = gm.getpattern(True)
pltdata = []

for p in pattern:

    res = int(p.hex(), 16)

    mv_list = []
    close_list = []
# Out:
# ---------------------------------------------------------------------------
# USBErrorIO                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 scope.io.tio1 = True
#       2 time.sleep(0.01)
#       3 scope.io.tio1 = False
#
# File c:\chipwhisperer570_64\cw\home\portable\chipwhisperer\software\chipwhisperer\common\utils\util.py:360, in DisableNewAttr.__setattr__(self, name, value)
#     359 def __setattr__(self, name, value):
# --> 360     if hasattr(self, '_new_attributes_disabled') and self._new_attributes_disabled and not hasattr(self, name):  # would this create a new attribute?
#     361         #raise AttributeError("Attempt to set unknown attribute in %s"%self.__class__, name)
#     362         other_logger.error("Setting unknown attribute {} in {}".format(name, self.__class__))
#     363         if hasattr(self, '_new_attributes_disabled_strict') and self._new_attributes_disabled_strict and not hasattr(self, name):
#
# File c:\chipwhisperer570_64\cw\home\portable\chipwhisperer\software\chipwhisperer\capture\scopes\cwhardware\ChipWhispererExtra.py:353, in GPIOSettings.tio1(self)
#     329 @property
#     330 def tio1(self):
#     331     """The function of the Target IO1 pin.
#     332
#     333     TIO1 can be used for the following functions:
#    (...)
#     351
#     352     """
# --> 353     return self._tioInternalToApi(self._getTio(0), self._getGpio(0))
#
# File c:\chipwhisperer570_64\cw\home\portable\chipwhisperer\software\chipwhisperer\capture\scopes\cwhardware\ChipWhispererExtra.py:459, in GPIOSettings._getTio(self, pinnum)
#     456 if pinnum < 0 or pinnum >= 4:
#     457     raise ValueError("Invalid PIN: %d. Valid range = 0-3." % pinnum, pinnum)
# --> 459 mode = self.cwe.getTargetIOMode(pinnum)
#     460 # Don't include GPIO state in mode check
#     461 mode &= ~self.cwe.IOROUTE_GPIO
#
# File c:\chipwhisperer570_64\cw\home\portable\chipwhisperer\software\chipwhisperer\capture\scopes\cwhardware\ChipWhispererExtra.py:1447, in CWExtraSettings.getTargetIOMode(self, IONumber)
#    1446 def getTargetIOMode(self, IONumber):
# -> 1447     data = self.oa.sendMessage(CODE_READ, ADDR_IOROUTE, Validate=False, maxResp=8)
#    1448     return data[IONumber]
#
# File c:\chipwhisperer570_64\cw\home\portable\chipwhisperer\software\chipwhisperer\capture\scopes\_OpenADCInterface.py:225, in OpenADCInterface.sendMessage(self, mode, address, payload, Validate, maxResp, readMask)
#     222         scope_logger.warning("The error trace below will show you what led to this:")
#     223         raise ValueError
# --> 225     return bytearray(self.serial.cmdReadMem(address, datalen))
#     227 else:
#     228     # Write output to memory
#     229     self.serial.cmdWriteMem(address, pba)
#
# File c:\chipwhisperer570_64\cw\home\portable\chipwhisperer\software\chipwhisperer\hardware\naeusb\naeusb.py:807, in NAEUSB.cmdReadMem(self, addr, dlen)
#     801 def cmdReadMem(self, addr : int, dlen : int) -> bytearray:
#     802     """
#     803     Send command to read over external memory interface from FPGA. Automatically
#     804     decides to use control-transfer or bulk-endpoint transfer based on data length.
#     805     """
# --> 807     return self.usbserializer.cmdReadMem(addr, dlen)
#
# File c:\chipwhisperer570_64\cw\home\portable\chipwhisperer\software\chipwhisperer\hardware\naeusb\naeusb.py:539, in NAEUSB_Backend.cmdReadMem(self, addr, dlen)
#     537 pload.extend(packuint32(addr))
#     538 try:
# --> 539     self.sendCtrl(cmd, data=pload)
#     540 except usb1.USBErrorPipe:
#     541     naeusb_logger.info("Attempting pipe error fix - typically safe to ignore")
#
# File c:\chipwhisperer570_64\cw\home\portable\chipwhisperer\software\chipwhisperer\hardware\naeusb\naeusb.py:505, in NAEUSB_Backend.sendCtrl(self, cmd, value, data)
#     503 if len(data) > 128:
#     504     naeusb_logger.error("The naeusb fw ctrl buffer is 128 bytes, but len(data) > 128. If you get a pipe error, this is why.")
# --> 505 self.handle.controlWrite(0x41, cmd, value, 0, data, timeout=self._timeout)
#
# File C:\CH0348~1\cw\home\portable\WPy64-31080\python-3.10.8.amd64\lib\site-packages\usb1\__init__.py:1330, in USBDeviceHandle.controlWrite(self, request_type, request, value, index, data, timeout)
#    1328 # pylint: enable=undefined-variable
#    1329 data, _ = create_initialised_buffer(data)
# -> 1330 return self._controlTransfer(request_type, request, value, index, data,
#    1331                              sizeof(data), timeout)
#
# File C:\CH0348~1\cw\home\portable\WPy64-31080\python-3.10.8.amd64\lib\site-packages\usb1\__init__.py:1307, in USBDeviceHandle._controlTransfer(self, request_type, request, value, index, data, length, timeout)
#    1301 def _controlTransfer(
#    1302         self, request_type, request, value, index, data, length, timeout):
#    1303     result = libusb1.libusb_control_transfer(
#    1304         self.__handle, request_type, request, value, index, data, length,
#    1305         timeout,
#    1306     )
# -> 1307     mayRaiseUSBError(result)
#    1308     return result
#
# File C:\CH0348~1\cw\home\portable\WPy64-31080\python-3.10.8.amd64\lib\site-packages\usb1\__init__.py:127, in mayRaiseUSBError(value, __raiseUSBError)
#     121 def mayRaiseUSBError(
#     122         value,
#     123         # Avoid globals lookup on call to work during interpreter shutdown.
#     124         __raiseUSBError=raiseUSBError,
#     125     ):
#     126     if value < 0:
# --> 127         __raiseUSBError(value)
#     128     return value
#
# File C:\CH0348~1\cw\home\portable\WPy64-31080\python-3.10.8.amd64\lib\site-packages\usb1\__init__.py:119, in raiseUSBError(value, __STATUS_TO_EXCEPTION_DICT, __USBError)
#     113 def raiseUSBError(
#     114         value,
#     115         # Avoid globals lookup on call to work during interpreter shutdown.
#     116         __STATUS_TO_EXCEPTION_DICT=STATUS_TO_EXCEPTION_DICT,
#     117         __USBError=USBError,
#     118     ): # pylint: disable=dangerous-default-value
# --> 119     raise __STATUS_TO_EXCEPTION_DICT.get(value, __USBError)(value)
#
# USBErrorIO: LIBUSB_ERROR_IO [-1]

# %%
scope = gm.scope
scope.clock.adc_mul = 1
scope.clock.clkgen_freq = 20E6

scope.glitch.enabled = True

scope.glitch.clk_src = "pll"
scope.glitch.trigger_src = "ext_single"

# %%
i = 50
NUM_ELEMENTS = i
print("Elements = %d"%i)

scope = gm.scope

scope.glitch.enabled = True

gm.build_and_load(NUM_ELEMENTS)

scope.io.tio1 = True
time.sleep(0.01)
scope.io.tio1 = False

pattern = gm.getpattern(False)

for p in pattern:
    bpat = bin(int(p.hex(), 16))
    print(bpat)
    print(bpat.count('1'))
    res = int(p.hex(), 16)
# Out:
# Elements = 50
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25
# 0b11111111111111111111111110000000
# 25

# %%
NUM_ELEMENTS = 3

scope = gm.scope

gm.build_and_load(NUM_ELEMENTS, "triggered", "GPIO4")


scope.glitch.ext_offset = 1
scope.glitch.repeat = 1
scope.glitch.output = "enable_only"

scope.glitch.width = 1200

scope.io.glitch_lp = True
scope.io.glitch_hp = True

scope.io.tio1 = True
time.sleep(0.01)
scope.io.tio1 = False

scope.arm()

time.sleep(0.01)
scope.io.tio4 = True
time.sleep(0.001)
scope.io.tio4 = False
time.sleep(0.1)

pattern = gm.getpattern(True)

pltdata = []
for p in pattern:
    value = bin(int(p.hex(), 16)).count('1')
    pltdata.append(value)

plt.plot(pltdata)
plt.show()
# Out:
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111000000000000000
# 11111111111111111000000000000000
# 11111111111111111111111100111000
# 11111111111111111100000000000000
# 11111111111111111111010000000000
# 11111111111111111111010000000000
# 11111111111111111100000000000000
# 11111111111111111111010000000000
# 11111111111111111100000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111100000000000000
# 11111111111111111110010000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111110000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000

# %% [markdown]
# Good stuff below here!!!

# %%
gm = GlitchMeter(None, None, dir="rtl")
# Out:
# scope.gain.gain                          changed from 0                         to 22
# scope.gain.db                            changed from 15.0                      to 25.091743119266056
# scope.adc.samples                        changed from 131124                    to 5000
# scope.clock.clkgen_freq                  changed from 0                         to 7363636.363636363
# scope.clock.adc_freq                     changed from 0                         to 29454545.454545453
# scope.io.tio1                            changed from serial_tx                 to serial_rx
# scope.io.tio2                            changed from serial_rx                 to serial_tx
# scope.io.hs2                             changed from None                      to clkgen
# scope.glitch.phase_shift_steps           changed from 0                         to 4592
# scope.trace.capture.trigger_source       changed from trace trigger, rule #0    to firmware trigger

# %%
scope = gm.scope
scope.clock.adc_mul = 1
scope.clock.clkgen_freq = 25E6

scope.glitch.enabled = True

scope.glitch.clk_src = "pll"
scope.glitch.trigger_src = "ext_single"

# %%
scope.clock.clkgen_freq = 25E6

# %%
scope.io.glitch_trig_mcx = "trigger"
scope.io.glitch_trig_mcx = "glitch"

# %%
NUM_ELEMENTS = 3

scope = gm.scope

gm.build_and_load(NUM_ELEMENTS, "triggered", "GPIO4")


scope.glitch.ext_offset = 1
scope.glitch.repeat = 1
scope.glitch.output = "enable_only"

scope.glitch.width = 1950
scope.glitch.offset = 3800

scope.io.glitch_lp = True
scope.io.glitch_hp = True

scope.io.tio1 = True
time.sleep(0.01)
scope.io.tio1 = False

scope.arm()

time.sleep(0.01)
scope.io.tio4 = True
time.sleep(0.001)
scope.io.tio4 = False
time.sleep(0.1)

pattern = gm.getpattern(True)

pltdata = []
for p in pattern:
    value = bin(int(p.hex(), 16)).count('1')
    pltdata.append(value)

plt.plot(pltdata)
plt.show()
# Out:
# Using env default (fomu)
# Setting shell vars.
# --------------------------------------------------------------------------------
# scons: `build' is up to date.
# ========================= [SUCCESS] Took 0.11 seconds ==========================
# 11111111111111111110000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111100000000000000
# 11111111111111110000000000000000
# 11111111111111111111010000000000
# 11111111111111111111111100111001
# 11111111111111111100000000000000
# 11111111111111111111110000100000
# 11111111111111111111010000000000
# 11111111111111111100000000000000
# 11111111111111111111110000100000
# 11111111111111111100000000000000
# 11111111111111111110000000000000
# 11111111111111111111010000000000
# 11111111111111111100000000000000
# 11111111111111111111010000000000
# 11111111111111111110000000000000
# 11111111111111111100000000000000
# 11111111111111111110010000000000
# 11111111111111111100000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111100000000000000
# 11111111111111111110010000000000
# 11111111111111111100000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111100000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111100000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111100000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000

# %%
#np.save("25mhz_tdc_1cycle_vglitch_pltdata.npy", pltdata)
#np.save("25mhz_tdc_1cycle_vglitch_pattern.npy", pattern)

# %%
NUM_ELEMENTS = 3

scope = gm.scope

gm.build_and_load(NUM_ELEMENTS, "triggered", "GPIO4")


scope.glitch.ext_offset = 1
scope.glitch.repeat = 4
scope.glitch.output = "glitch_only"

scope.glitch.width = 1950
scope.glitch.offset = 3800

scope.io.glitch_lp = True
scope.io.glitch_hp = True

scope.io.tio1 = True
time.sleep(0.01)
scope.io.tio1 = False

scope.arm()

time.sleep(0.01)
scope.io.tio4 = True
time.sleep(0.001)
scope.io.tio4 = False
time.sleep(0.1)

pattern = gm.getpattern(True)

pltdata = []
for p in pattern:
    value = bin(int(p.hex(), 16)).count('1')
    pltdata.append(value)

plt.plot(pltdata)
plt.show()
# Out:
# Using env default (fomu)
# Setting shell vars.
# --------------------------------------------------------------------------------
# scons: `build' is up to date.
# ========================= [SUCCESS] Took 0.13 seconds ==========================
# 11111111111111111110000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111100000000000000
# 11111111111111111000000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111111010000000000
# 11111111111111111111111000100000
# 11111111111111111111111111111111
# 00000001111111111111111111111111
# 00000011111111111111111111111111
# 11111111111111111111111111111111
# 11111111111111111111111111111111
# 11111111111111111111111100111001
# 11111111111111111111111000111000
# 11111111111111111111111100111000
# 11111111111111111111010000000000
# 11111111111111111111110000100000
# 11111111111111111111010000000000
# 11111111111111111110010000000000
# 11111111111111111111010000000000
# 11111111111111111110000000000000
# 11111111111111111110010000000000
# 11111111111111111110010000000000
# 11111111111111111110000000000000
# 11111111111111111110010000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111100000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000

# %%
#np.save("25mhz_tdc_4cycleglitchonly_vglitch_pltdata.npy", pltdata)
#np.save("25mhz_tdc_4cycleglitchonly_vglitch_pattern.npy", pattern)

# %%
EMFI Stuff:

# %%
scope.clock.clkgen_freq = 25E6

# %%
NUM_ELEMENTS = 3

scope = gm.scope

gm.build_and_load(NUM_ELEMENTS, "triggered", "GPIO4")


scope.glitch.ext_offset = 0
scope.glitch.repeat = 1
scope.glitch.output = "enable_only"

scope.glitch.width = 1950
scope.glitch.offset = 3800

scope.io.glitch_lp = True
scope.io.glitch_hp = True

scope.io.tio1 = True
time.sleep(0.01)
scope.io.tio1 = False

scope.arm()

time.sleep(0.01)
scope.io.tio4 = True
time.sleep(0.001)
scope.io.tio4 = False
time.sleep(0.1)

pattern = gm.getpattern(True)

pltdata = []
for p in pattern:
    value = bin(int(p.hex(), 16)).count('1')
    pltdata.append(value)

plt.plot(pltdata)
plt.show()
# Out:
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111110000000000000
# 11111111111111111111010000000000
# 11111111111111111111111000110000
# 11111111111111111111111000110000
# 11111111111111111111110000100000
# 11111111111111111111010000000000
# 11111111111111111110000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111000000000000000
# 11111111111111111000000000000000
# 11111111111111111000000000000000
# 11111111111111111000000000000000
# 11111111111111111000000000000000
# 11111111111111111000000000000000
# 11111111111111111000000000000000
# 11111111111111111000000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000

# %%
#np.save("hwaes_25mhz_tdc_picoemp_14cycftint_pltdata.npy", pltdata)
#np.save("hwaes_25mhz_tdc_picoemp_14cycftint_pattern.npy", pattern)

#np.save("25mhz_tdc_picoemp_128pl_pltdata.npy", pltdata)
#np.save("25mhz_tdc_picoemp_64pl_pltdata.npy", pltdata)
#np.save("25mhz_tdc_picoemp_32pl_pltdata.npy", pltdata)
#np.save("25mhz_tdc_picoemp_16pl_pltdata.npy", pltdata)
np.save("25mhz_tdc_picoemp_14pl_pltdata.npy", pltdata)

# %%
NUM_ELEMENTS = 3

scope = gm.scope

gm.build_and_load(NUM_ELEMENTS, "triggered", "GPIO4")


scope.glitch.ext_offset = 1
scope.glitch.repeat = 5
scope.glitch.output = "enable_only"

scope.glitch.width = 1950
scope.glitch.offset = 3800

scope.io.glitch_lp = True
scope.io.glitch_hp = True

scope.io.tio1 = True
time.sleep(0.01)
scope.io.tio1 = False

scope.arm()

time.sleep(0.01)
scope.io.tio4 = True
time.sleep(0.001)
scope.io.tio4 = False
time.sleep(0.1)

pattern = gm.getpattern(True)

pltdata = []
for p in pattern:
    value = bin(int(p.hex(), 16)).count('1')
    pltdata.append(value)

plt.plot(pltdata)
plt.show()
# Out:
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111110000000000000
# 11111111111111111110010000000000
# 11111111111111111111010000000000
# 11111111111111111111110000000000
# 11111111111111111111010000000000
# 11111111111111111111010000000000
# 11111111111111111110010000000000
# 11111111111111111110000000000000
# 11111111111111111110000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000

# %%
#np.save("hwaes_25mhz_tdc_4cyclesenable_bbi_pltdata.npy", pltdata)
#np.save("hwaes_25mhz_tdc_4cyclesenable_bbi_pattern.npy", pattern)

# %%
NUM_ELEMENTS = 3

scope = gm.scope

gm.build_and_load(NUM_ELEMENTS, "triggered", "GPIO4")


scope.glitch.ext_offset = 1
scope.glitch.repeat = 10
scope.glitch.output = "enable_only"

scope.glitch.width = 1950
scope.glitch.offset = 3800

scope.io.glitch_lp = True
scope.io.glitch_hp = True

scope.io.tio1 = True
time.sleep(0.01)
scope.io.tio1 = False

scope.arm()

time.sleep(0.01)
scope.io.tio4 = True
time.sleep(0.001)
scope.io.tio4 = False
time.sleep(0.1)

pattern = gm.getpattern(True)

pltdata = []
for p in pattern:
    value = bin(int(p.hex(), 16)).count('1')
    pltdata.append(value)

plt.plot(pltdata)
plt.show()
# Out:
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111110000000000000
# 11111111111111111111010000000000
# 11111111111111111111111000110000
# 11111111111111111111111100111001
# 11111111111111111111111111111111
# 11111111111111111111111111111111
# 10111111111111111111111111111111
# 00100111111111111111111111111111
# 00000011111111111111111111111111
# 00000001011111111111111111111111
# 11000000001010111111111111111111
# 11010000000010111111111111111111
# 11011000000010101111111111111111
# 11010000000010111111111111111111
# 00000011111111111111111111111111
# 00101111111111111111111111111111
# 11111111111111111111111111111111
# 11111111111111111111111100111001
# 11111111111111111111111000110000
# 11111111111111111111110000000000
# 11111111111111111111010000000000
# 11111111111111111111010000000000
# 11111111111111111110010000000000
# 11111111111111111110000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000

# %%
#np.save("sw_25mhz_tdc_10cyclesenable_bbi_pltdata.npy", pltdata)
#np.save("sw_25mhz_tdc_10cyclesenable_bbi_pattern.npy", pattern)

# %%
NUM_ELEMENTS = 3

scope = gm.scope

gm.build_and_load(NUM_ELEMENTS, "triggered", "GPIO4")


scope.glitch.ext_offset = 1
scope.glitch.repeat = 4
scope.glitch.output = "glitch_only"

scope.glitch.width = 1950
scope.glitch.offset = 3800

scope.io.glitch_lp = False
scope.io.glitch_hp = False

scope.io.tio1 = True
time.sleep(0.01)
scope.io.tio1 = False

scope.arm()

time.sleep(0.01)
scope.io.tio4 = True
time.sleep(0.001)
scope.io.tio4 = False
time.sleep(0.1)

pattern = gm.getpattern(True)

pltdata = []
for p in pattern:
    value = bin(int(p.hex(), 16)).count('1')
    pltdata.append(value)

plt.plot(pltdata)
plt.show()
# Out:
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111111111000110000
# 00000000000000001111111111111111
# 00000011111111111111111111111111
# 00000011111111111111111111111111
# 11111111111111111111111000110000
# 11111111111111111111111111111111
# 11111111111111111111111000110000
# 11111111111111111000000000000000
# 11111111111111111100000000000000
# 11111111111111110000000000000000
# 11111111111101010000000000000000
# 11111111111101010000000000000000
# 11111111110101000000000000000000
# 11111111111101010000000000000000
# 11111111111101010000000000000000
# 11111111111101010000000000000000
# 11111111111111010000000000000000
# 11111111111111010000000000000000
# 11111111111111010000000000000000
# 11111111111111111000000000000000
# 11111111111111010000000000000000
# 11111111111111111000000000000000
# 11111111111111111000000000000000
# 11111111111111111000000000000000
# 11111111111111111000000000000000
# 11111111111111111000000000000000
# 11111111111111111100000000000000
# 11111111111111111000000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000
# 11111111111111111100000000000000

# %%
#np.save("sw_25mhz_tdc_15picoempcycles_pltdata.npy", pltdata)
#np.save("sw_25mhz_tdc_15picoempcycles_pattern.npy", pattern)
